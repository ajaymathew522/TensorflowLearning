# %%
# !pip install tensorflow==2.0.1
import tensorflow as tf
print(tf.__version__)
# Out:
# Requirement already satisfied: tensorflow==2.0.1 in /usr/local/lib/python3.6/dist-packages (2.0.1)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (2.0.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (1.12.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (0.2.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (3.2.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (1.24.3)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (1.12.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (0.9.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (1.18.2)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (0.34.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (3.10.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (0.8.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (1.0.8)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.1) (2.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==2.0.1) (46.0.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==2.0.1) (2.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (1.7.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (3.2.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (2.21.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (0.2.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (4.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.1) (0.4.8)
# 2.0.1

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
N = 1000
X = np.random.random((N, 2)) *6 -3
Y = np.cos(2*X[:,0])+ np.cos(3*X[:,1])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(128, input_shape=(2,), activation='relu'),
                                    tf.keras.layers.Dense(1)
])

# %%
opt = tf.keras.optimizers.Adam(0.01)
model.compile(optimizer=opt, loss='mse')
r = model.fit(X, Y, epochs=100)
# Out:
# Train on 1000 samples
# Epoch 1/100
# 1000/1000 [==============================] - 0s 436us/sample - loss: 0.9842
# Epoch 2/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.9315
# Epoch 3/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.8765
# Epoch 4/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.8447
# Epoch 5/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.7797
# Epoch 6/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.7274
# Epoch 7/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.6654
# Epoch 8/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.6497
# Epoch 9/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.6143
# Epoch 10/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.5776
# Epoch 11/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.5222
# Epoch 12/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.5638
# Epoch 13/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.4967
# Epoch 14/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.5003
# Epoch 15/100
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.5038
# Epoch 16/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.4536
# Epoch 17/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.4721
# Epoch 18/100
# 1000/1000 [==============================] - 0s 48us/sample - loss: 0.5045
# Epoch 19/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.4604
# Epoch 20/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.4688
# Epoch 21/100
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.4891
# Epoch 22/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.4904
# Epoch 23/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.4597
# Epoch 24/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.4386
# Epoch 25/100
# 1000/1000 [==============================] - 0s 50us/sample - loss: 0.4613
# Epoch 26/100
# 1000/1000 [==============================] - 0s 37us/sample - loss: 0.4103
# Epoch 27/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.4150
# Epoch 28/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.4196
# Epoch 29/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.4260
# Epoch 30/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.3820
# Epoch 31/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.3747
# Epoch 32/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.3879
# Epoch 33/100
# 1000/1000 [==============================] - 0s 48us/sample - loss: 0.3753
# Epoch 34/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.3523
# Epoch 35/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.3051
# Epoch 36/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.3067
# Epoch 37/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.2827
# Epoch 38/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.2932
# Epoch 39/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.2373
# Epoch 40/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.2627
# Epoch 41/100
# 1000/1000 [==============================] - 0s 37us/sample - loss: 0.2210
# Epoch 42/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.1624
# Epoch 43/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.1406
# Epoch 44/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.1262
# Epoch 45/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.1134
# Epoch 46/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0922
# Epoch 47/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.0789
# Epoch 48/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.0695
# Epoch 49/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.0626
# Epoch 50/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.0513
# Epoch 51/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.0492
# Epoch 52/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.0387
# Epoch 53/100
# 1000/1000 [==============================] - 0s 51us/sample - loss: 0.0342
# Epoch 54/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.0335
# Epoch 55/100
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.0253
# Epoch 56/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0207
# Epoch 57/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.0159
# Epoch 58/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.0176
# Epoch 59/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0269
# Epoch 60/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.0130
# Epoch 61/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.0170
# Epoch 62/100
# 1000/1000 [==============================] - 0s 52us/sample - loss: 0.0183
# Epoch 63/100
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.0208
# Epoch 64/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.0110
# Epoch 65/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.0136
# Epoch 66/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.0130
# Epoch 67/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.0112
# Epoch 68/100
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.0096
# Epoch 69/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.0110
# Epoch 70/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.0080
# Epoch 71/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.0123
# Epoch 72/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.0200
# Epoch 73/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.0135
# Epoch 74/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.0114
# Epoch 75/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.0110
# Epoch 76/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0100
# Epoch 77/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.0075
# Epoch 78/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.0082
# Epoch 79/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.0336
# Epoch 80/100
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.0314
# Epoch 81/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.0124
# Epoch 82/100
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.0084
# Epoch 83/100
# 1000/1000 [==============================] - 0s 36us/sample - loss: 0.0087
# Epoch 84/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.0073
# Epoch 85/100
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.0082
# Epoch 86/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.0073
# Epoch 87/100
# 1000/1000 [==============================] - 0s 48us/sample - loss: 0.0141
# Epoch 88/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0129
# Epoch 89/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0216
# Epoch 90/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.0117
# Epoch 91/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.0052
# Epoch 92/100
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.0089
# Epoch 93/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.0064
# Epoch 94/100
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.0070
# Epoch 95/100
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.0055
# Epoch 96/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0055
# Epoch 97/100
# 1000/1000 [==============================] - 0s 42us/sample - loss: 0.0057
# Epoch 98/100
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.0082
# Epoch 99/100
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.0062
# Epoch 100/100
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.0056

# %%
plt.plot(r.history['loss'], label = 'loss')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1],Y)
line = np.linspace(-3, 3, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1],Y)
line = np.linspace(-5, 5, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()
