# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 2.x selected.
# 2.1.0

# %%
from  tensorflow.keras.layers import Dense, Input, SimpleRNN, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
N = 2
T = 10
D = 3
K = 2
X=np.random.randn(N, T, D)

# %%
M = 5
i = Input(shape=(T, D))
x = SimpleRNN(M)(i)
x = Dense(K)(x)
model = Model(i, x)

# %%
yhat = model.predict(X)
print(yhat)
# Out:
# [[ 0.30264553 -1.2540823 ]
#  [-0.06527495 -0.14553392]]

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 10, 3)]           0
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 5)                 45
# _________________________________________________________________
# dense (Dense)                (None, 2)                 12
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers[1].get_weights()
# Out:
# [array([[-0.835325  , -0.43837366, -0.8602651 , -0.840961  , -0.30345136],
#         [ 0.48221272,  0.25664145, -0.46169537, -0.35755587, -0.71285635],
#         [-0.46183145, -0.86336577,  0.70048267,  0.19538027,  0.5346163 ]],
#        dtype=float32),
#  array([[ 0.564898  ,  0.34723783,  0.3816683 ,  0.08526643,  0.6382593 ],
#         [-0.11933165,  0.7090189 ,  0.3607549 ,  0.26568583, -0.53133696],
#         [ 0.7058285 , -0.06054434, -0.4667623 ,  0.3844169 , -0.3640014 ],
#         [ 0.32395872,  0.22828117, -0.06675725, -0.87991256, -0.25344774],
#         [ 0.25200596, -0.5665157 ,  0.7084219 , -0.01086944, -0.33700624]],
#        dtype=float32),
#  array([0., 0., 0., 0., 0.], dtype=float32)]

# %%
a, b, c = model.layers[1].get_weights()
print(a.shape, b.shape, c.shape)
# Out:
# (3, 5) (5, 5) (5,)

# %%
Wx, Wh, bh = model.layers[1].get_weights()
Wo, bo = model.layers[2].get_weights()

# %%
for i in range(N):
  h_last = np.zeros(M)
  x = X[i]
  Yhats = []
  for t in range(T):
    h = np.tanh(x[t].dot(Wx) + h_last.dot(Wh) + bh)
    y = h.dot(Wo) + bo
    Yhats.append(y)

    h_last = h
  print(Yhats[-1])
# Out:
# [ 0.30264551 -1.25408214]
# [-0.06527501 -0.14553399]
